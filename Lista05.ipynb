# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoGSP/ColabPython/blob/master/Lista05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Disciplina: Probabilidade e Estatística
# Aluno: João Guilherme Santiago Pereira - 2014290013
# Lista 5

# Questão 01
"""
import statistics
from scipy.stats.mstats import gmean

Cons_Sal = [10, 13, 17, 9, 8, 11, 13, 7]

MedSimples = statistics.mean(Cons_Sal)
MedHarmo = statistics.harmonic_mean(Cons_Sal)
MedGeo = gmean(Cons_Sal)
Mod = statistics.mode(Cons_Sal)
Varia = statistics.variance(Cons_Sal)
DesvPadr = statistics.stdev(Cons_Sal)

print('Resultados dos calculos estatísticos:')
print('Média Aritmética Simples: ' + str(round(MedSimples, 2)))
print('Média Harmônica: ' + str(round(MedHarmo, 2)))
print('Média Geométrica: ' + str(round(MedGeo, 2)))
print('Moda: ' + str(round(Mod, 2)))
print('Variância: ' + str(round(Varia, 2)))
print('Desvio padrão: ' + str(round(DesvPadr, 2)))"""

# Questão 02
"""
import statistics
from scipy.stats.mstats import gmean

Esca_Ansie = [67, 75, 63, 72, 77, 78, 81, 77, 80]

MedSimples = statistics.mean(Esca_Ansie)
MedHarmo = statistics.harmonic_mean(Esca_Ansie)
MedGeo = gmean(Esca_Ansie)
Mod = statistics.mode(Esca_Ansie)
Mediana = statistics.median(Esca_Ansie)
Varia = statistics.variance(Esca_Ansie)
DesvPadr = statistics.stdev(Esca_Ansie)

print('Resultados dos calculos estatísticos:')
print('Média Aritmética Simples: ' + str(round(MedSimples, 2)))
print('Média Harmônica: ' + str(round(MedHarmo, 2)))
print('Média Geométrica: ' + str(round(MedGeo, 2)))
print('Moda: ' + str(round(Mod, 2)))
print('Mediana: ' + str(round(Mediana, 2)))
print('Variância: ' + str(round(Varia, 2)))
print('Desvio padrão: ' + str(round(DesvPadr, 2)))"""

# Questão 03
"""
import statistics

Prod_Leite = [4.0, 4.5, 5.0, 5.0, 5.0, 5.5, 6.0, 6.0, 6.5, 6.5, 6.5,
              6.5, 7.0, 7.0, 7.0, 7.0, 7.0, 7.0, 7.5, 8.5, 9.0, 9.0,
              9.0, 9.5, 10.0, 10.0, 10.5, 10.5, 11.0, 12.0, 12.5, 13.0, 13.0]

DesvPadr = statistics.stdev(Prod_Leite)
MedSimples = statistics.mean(Prod_Leite)
CV = (DesvPadr/MedSimples) * 100

print('O coeficiente de variação desse conjunto é ' + str(round(CV, 2)))"""

# Questão 04
"""
import statistics

Prod_Cafe = [12, 15, 18, 22, 17, 14, 18, 23, 29, 12]

MedSimples = statistics.mean(Prod_Cafe)
Mediana = statistics.median(Prod_Cafe)
DesvPadr = statistics.stdev(Prod_Cafe)

print('Resultado dos calculos estatisticos da produção de café: ')
print('Média: ' + str(round(MedSimples, 2)))
print('Mediana: ' + str(round(Mediana, 2)))
print('Desvio Padrão: ' + str(round(DesvPadr)))"""

# Questão 05
"""
import statistics
from scipy.stats.mstats import gmean

Notas = []

while True:
    X = int(input('Insira a nota do aluno: '))
    if X == -999:
        break
    if X < 0 or X > 10:
        print('Nota inválida!')
        print('Insira um valor entre 0 e 10!')
    else:
        Notas.append(X)
        
MedSimples = statistics.mean(Notas)
MedHarmo = statistics.harmonic_mean(Notas)
MedGeo = gmean(Notas)
Moda = statistics.mode(Notas)
Varia = statistics.variance(Notas)
DesvPadr = statistics.stdev(Notas)
CV = (DesvPadr/MedSimples) * 100

print('Resultado dos calculos estatisticos são: ')
print('Média Simples : ' + str(round(MedSimples, 2)))
print('Média Harmônica: ' + str(round(MedHarmo, 2)))
print('Média Geométrica: ' + str(round(MedGeo, 2)))
print('Moda: ' + str(round(Moda, 2)))
print('Variância: ' + str(round(Varia, 2)))
print('Desvio Padrão: ' + str(round(DesvPadr)))
print('Coeficiente de variação: ' + str(round(CV, 2)))"""

# Questão 06
"""
Notas = []

for _ in range(0, 3):
    Notas.append(int(input('Insira a nota: ')))
    
Med_Pond = (Notas[0]*3 + Notas[1]*4 + Notas[2]*3) / 3
print(str(round(Med_Pond, 2)))"""
# Out:
# Insira a nota: 1
# Insira a nota: 2
# Insira a nota: 3
# 6.67
