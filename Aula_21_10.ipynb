# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoGSP/ColabPython/blob/master/Aula_21_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Estruturas de controle e laçõs de repeetição I

'''fome = False
if fome: 
  print('Comida')
else: 
  print('Sem comida')'''

'''Nota = 7 
if Nota<0 or Nota>10:
  print('Nota Errada')
else:
  print('Nota Valida')'''

'''Local = input('Onde Você está? ')
if Local == 'casa':
  print('Está em casa')
elif Local == 'mercado':
  print('Está no mercado')
elif Local == 'banco':
  print('Está no banco')
else:
  print('Está em outro lugar')'''

'''frase = 'Meu carro não liga de manhã quando está frio'
p = 'avião'

if p  in frase:
  print('A palavra/letra ' + p + ' está presente na frase')
else:
  print('A palavra/letra ' + p + ' não está presente na frase')'''

'''l1 = ['carro', 32, True, 99.99]
print(50 in l1)
print('carro' in l1)
print('car' in l1)
if 'carro' in l1:
  print('Lista com a palavra carro')
else:
  print('Lista sem a palavra carro')

if 'moto' in l1:
  print('Lista com a palavra moto')
else:
  print('Lista sem a palavra moto')

if 99.999 in l1:
  print('Presente')
else:
  print('Ausente')'''

'''.lower()
#coloca tudo em minusculo
'''
'''Nota = input('Insira a nota do aluno: ')
Nota = float(Nota)
if Nota<0 or Nota>10:
  print('Nota errada!')
elif Nota < 5:
  print('Reprovado')
else:
  print('Aprovado')'''

'''l2 = [10, 11, 12, 13, 'Catorze', False, [9, 3, 5]]
for x in l2:
  print(x)

frase = 'Letras e'
for _ in frase:
  print(_)'''

'''l3 = [1, 2, 3, 4, 5, 6]
Soma = 0
for cont in l3:
  Soma += cont #Soma = Soma + cont
  print(Soma)
  if cont % 2 == 0:
    print('Número:', cont, 'é Par')
  else:
    print('Número:', cont, 'é impar')'''

'''l4 = range(2, 12, 3)
for _ in l4:
  if _ % 2 == 0:
    print('Número:', _, 'é Par')
  else:
    print('Número:', _, 'é impar')'''

'''for _ in range(1,11):
  if _ == 7:
    break
  print(_)'''

'''for _ in range(1,11):
  if _ == 7:
    continue
  print(_)'''

'''for _ in range(1,11):
  if _ == 7:
    pass
  print(_)'''

'''lista = [(1,2), (3,4), (5,6), (7,8)]
for _ in lista:
  print(_)
print('---------')
for (x,y) in lista:
  print(x*-2,y*2)
print('----------')
for (x,y) in lista:
  z = x*y
  print(z)'''

'''dic = {'a':1, 'b':2, 'c':3}
for _ in dic:
  print(_)
print('----------')
for _ in dic.values():
  print(_)
print('----------')
for _ in dic.items():
  print(_)
print('----------')
for x,y in dic.items():
  print(x)
  print(y)
print(x + 'def')
print(y**3)'''

'''l5 = [65, 'dois', 85.6, 3, 12/2, 4**3]
for _ in range(0, len(l5)): # --> (0, 1, 2, 3, 4, 5)
  print('Índice:', _, 'Valor:', l5[_])'''

'''l6 = [65, 'dois', 85.6, 3, 12/2, 4**3]
for _ in range(0, len(l6), 2): # --> (0, 2, 4)
  print('Índice:', _, 'Valor:', l6[_])'''

'''#Atividade:
#Faça uma oração e tente entender isso aqui...
for n in range(2,10): # n --> (2, 3, 4, 5, 6, 7, 8, 9)
  for x in range(2,n): # 1° x --> (2, 1); 2° x --> (2)
    if n % x == 0:
      print(n, 'igual a ', x, '*', n/x)
      break
    else:
      print(n)'''
# Out:
# 3
# 4 igual a  2 * 2.0
# 5
# 5
# 5
# 6 igual a  2 * 3.0
# 7
# 7
# 7
# 7
# 7
# 8 igual a  2 * 4.0
# 9
# 9 igual a  3 * 3.0
